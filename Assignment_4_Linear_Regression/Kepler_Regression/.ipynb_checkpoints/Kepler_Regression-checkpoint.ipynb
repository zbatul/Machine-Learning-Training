# %% [markdown]
# ## Regression Problem : Predict the orbital period of the planets from the data and check if they confirm to Kepler’s Third Law of Planetary Motion.

# %%
# import statements
import pandas as pd
import math
from sklearn import linear_model, cross_validation
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
# Out:
# /home/user/dummy/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Reading the data file and preprocessing
kepler_data = pd.read_csv("Ex01_Kepler_Regression.csv")
kepler_data['planet'] = pd.Categorical(kepler_data.planet).codes
kepler_data = kepler_data.drop('planet', axis=1)
kepler_data = kepler_data.apply(lambda x: np.log(x))

# %%
y_reg = kepler_data['OrbitalPeriod']
x_reg = kepler_data.drop(['OrbitalPeriod'], axis=1)

# %% [markdown]
# ## Basic Analysis : Correlation Matrix

# %%
f, ax = plt.subplots(figsize=(12, 8))
corr = kepler_data.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## Scatter plots of each feature with the target to see relationship

# %%
plt.scatter(kepler_data.SemiMajorAxis, kepler_data.OrbitalPeriod)
plt.xlabel("Semi Major Axis")
plt.ylabel("Orbital Period")
plt.title("Semi Major Axis v/s Orbital Period")
plt.show()

# %%
plt.scatter(kepler_data.Volume, kepler_data.OrbitalPeriod)
plt.xlabel("Volume")
plt.ylabel("Orbital Period")
plt.title("Volume v/s Orbital Period")
plt.show()

# %%
plt.scatter(kepler_data.EscapeVelocity, kepler_data.OrbitalPeriod)
plt.xlabel("Escape Velocity")
plt.ylabel("Orbital Period")
plt.title("Escape velocity v/s Orbital Period")
plt.show()

# %%
plt.scatter(kepler_data.Density, kepler_data.OrbitalPeriod)
plt.xlabel("Density")
plt.ylabel("Orbital Period")
plt.title("Density v/s Orbital Period")
plt.show()

# %%
# Creating the test and train datasets
x_train, x_test, y_train, y_test = cross_validation.train_test_split(x_reg, y_reg, test_size=0.33, random_state=5)

# %%
# Standardising the data
y_train_sc = (y_train-y_train.mean())/y_train.std()
x_train_sc = (x_train-x_train.mean())/x_train.std()
x_test_sc = (x_test-x_test.mean())/x_test.std()

# %% [markdown]
# ## 1. Linear Regression Model

# %%
reg = linear_model.LinearRegression(normalize=True)
reg.fit (x_train_sc, y_train_sc)
tr_coeffs = reg.coef_
tr_resi = reg.residues_
tr_intr = reg.intercept_
print(pd.Series(tr_coeffs, index=x_test_sc.columns))
print("Residuals: ", tr_resi)
print("Intercept: ", tr_intr)
# Out:
# SemiMajorAxis     1.040127
# Volume           -0.025135
# EscapeVelocity   -0.039370
# Density           0.015071
# dtype: float64
# Residuals:  0.901691460265
# Intercept:  -1.34032231394e-16
# /home/user/dummy/lib/python3.5/site-packages/sklearn/utils/deprecation.py:70: DeprecationWarning: Function residues_ is deprecated; ``residues_`` is deprecated and will be removed in 0.19
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# PREDICT THE MODEL

# %%
pred_lin = reg.predict(x_test_sc)
pred_lin = (pred_lin*y_test.std())+y_test.mean()

# %%
plt.scatter(np.exp(y_test), np.exp(pred_lin))
plt.plot(np.exp(y_test), np.exp(y_test))
plt.xlabel("Actual Orbital Period")
plt.ylabel("Predicted Orbital Period")
plt.title("Actual Orbital Period v/s Predicted Orbital Period")
plt.show()

# %% [markdown]
# ERROR CALCULATION

# %%
errors_abs = np.abs(np.exp(y_test)-np.exp(pred_lin))
errors = np.exp(y_test)-np.exp(pred_lin)

# %%
errors.mean()
# Out:
# 0.18885365790485981

# %%
plt.scatter(np.exp(y_test), errors)
plt.xlabel("Predicted Orbital Period")
plt.ylabel("Error")
plt.title("Predicted Orbital Period v/s Error")
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
plt.hist(errors)
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %% [markdown]
# BOX PLOT

# %%
y = pd.DataFrame(errors)
y.plot(kind='box')
plt.title("Box Plot")
plt.show()

# %% [markdown]
# ## 2. Linear Regression Model : Ridge

# %%
alphas = np.linspace(0.01,200,1000)*0.5

# %%
ridge = linear_model.Ridge(normalize=True)
coefs = []
for a in alphas_r:
    ridge.set_params(alpha=a)
    ridge.fit(np.array(x_train_sc), np.array(y_train_sc))
    coefs.append(ridge.coef_)
ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title("Ridge Regression")
plt.show()

# %%
ridgecv = linear_model.RidgeCV(alphas=alphas, scoring='neg_mean_squared_error', normalize=True)
ridgecv.fit(np.array(x_train_sc), np.array(y_train_sc))
ridgecv.alpha_
ridge.set_params(alpha=ridgecv.alpha_)
ridge.fit(np.array(x_train_sc), np.array(y_train_sc))
pred = ridge.predict(x_test_sc)
mean_squared_error(np.exp(y_test), np.exp((pred*y_test.std())+y_test.mean()))
# Out:
# 1013.4869495067526

# %%
print(pd.Series(ridge.coef_, index=x_test_sc.columns))
print("Intercept: ", ridge.intercept_)
print("Aplha: ", ridge.alpha)
# Out:
# SemiMajorAxis     1.019115
# Volume           -0.024617
# EscapeVelocity   -0.035948
# Density          -0.000311
# dtype: float64
# Intercept:  -1.3110615554e-16
# Aplha:  0.005

# %% [markdown]
# PREDICT THE MODEL

# %%
pred_ridge = np.exp((ridge.predict(x_test_sc)*y_test.std())+y_test.mean())

# %%
plt.scatter(np.exp(y_test), pred_ridge)
plt.plot(np.exp(y_test), np.exp(y_test))
plt.xlabel("Actual Orbital Period")
plt.ylabel("Predicted Orbital Period")
plt.title("Actual Orbital Period v/s Predicted Orbital Period")
plt.show()

# %% [markdown]
# ERROR CALCULATION

# %%
errors_abs = np.abs(np.array(np.exp(y_test))-pred_ridge)
errors = np.array(np.exp(y_test)).reshape(33,1)-pred_ridge.reshape(33,1)

# %%
plt.scatter(np.array(np.exp(y_test)).reshape(33,1), errors)
plt.xlabel("Predicted Orbital Period")
plt.ylabel("Error")
plt.title("Predicted Orbital Period v/s Error")
plt.show()

# %% [markdown]
# HISTOGRAM : RIDGE

# %%
y = pd.DataFrame(errors)
y.plot(kind = 'hist')
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %% [markdown]
# BOX PLOT

# %%
y.plot(kind = 'box')
plt.title("Box Plot")
plt.show()

# %% [markdown]
# ## 3. Linear Regression Model : Lasso

# %%
alphas = np.linspace(0.0001,1,1000)*0.5

# %%
lasso = linear_model.Lasso(max_iter = 10000, normalize=True)
coeffs = []
for al in alphas:
    lasso.set_params(alpha=al)
    lasso.fit(np.array(x_train_sc), np.array(y_train_sc))
    coeffs.append(lasso.coef_)
ax = plt.gca()
ax.plot(2*alphas, coeffs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title("Lasso regression")
plt.show()

# %%
lassocv = linear_model.LassoCV(alphas=None, cv=10, max_iter=100000, normalize=True)
lassocv.fit(np.array(x_train_sc), np.array(y_train_sc))
lasso.set_params(alpha=lassocv.alpha_)
lasso.fit(np.array(x_train_sc), np.array(y_train_sc))
pred = lasso.predict(x_test_sc)
mean_squared_error(np.exp(y_test), np.exp((pred*y_test.std())+y_test.mean()))
# Out:
# 1013.5676650099617

# %%
print(pd.Series(lasso.coef_, index=x_test_sc.columns))
print("Intercept: ", lasso.intercept_)
print("Aplha: ", lasso.alpha)
# Out:
# SemiMajorAxis     1.017694
# Volume           -0.021735
# EscapeVelocity   -0.032107
# Density           0.000000
# dtype: float64
# Intercept:  -1.33322421911e-16
# Aplha:  0.000394012773051

# %% [markdown]
# PREDICT THE MODEL

# %%
pred_lasso = np.exp((lasso.predict(x_test_sc)*y_test.std())+y_test.mean())

# %%
plt.scatter(np.exp(y_test), pred_lasso)
plt.plot(np.exp(y_test), np.exp(y_test))
plt.xlabel("Actual Orbital Period")
plt.ylabel("Predicted Orbital Period")
plt.title("Actual Orbital Period v/s Predicted Orbital Period")
plt.show()

# %% [markdown]
# ERROR CALCULATION

# %%
errors_abs = np.abs(np.array(np.exp(y_test))-pred_lasso)
errors = np.array(np.exp(y_test)).reshape(33,1)-pred_lasso.reshape(33,1)

# %%
errors.mean()
# Out:
# 1.2416594116881869

# %%
plt.scatter(np.array(np.exp(y_test)).reshape(33,1), errors)
plt.xlabel("Predicted Orbital Period")
plt.ylabel("Error")
plt.title("Predicted Orbital Period v/s Error")
plt.show()

# %% [markdown]
# HISTOGRAM : LASSO

# %%
y = pd.DataFrame(errors)
y.plot(kind = 'hist')
plt.xlabel("Error")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

# %% [markdown]
# BOX PLOT

# %%
y.plot(kind = 'box')
plt.title("Box plot")
plt.show()
